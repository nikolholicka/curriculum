# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import pandas as pd
import re
import numpy as np
import requests
from bs4 import BeautifulSoup
import time

# %%
response = requests.get('https://www.residentadvisor.net/events')
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en,ja,es">
# <head id="_x1"><title>
# 	RA: Events in Manchester, United Kingdom
# </title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="en,ja,es" http-equiv="content-language"/><meta content="RA: Resident Advisor" name="Description"/><meta content="RA, residentadvisor, resident, advisor, music, ra, events, in, manchester, united, kingdom" name="Keywords"/><meta content="Resident Advisor" name="Author"/><meta content="Resident Advisor" property="og:site_name"/><meta content="712773712080127" property="fb:app_id"/><link href="/bundles/default-css?v=73_zn4f444Ms1nbtnaddvbDUe15CsJN6vhoNK7oQovg1" rel="stylesheet"/>
# <meta content="app-id=981952703, app-argument=ra-guide://search" name="apple-itunes-app"/><link href="/bundles/cat-listings-css?v=w7DJdRHlwvlSlvivLjU2DnToUsYFU7IYixebCORYtxw1" rel="stylesheet"/>
# <link href="/favicon.ico" rel="icon" type="image/vnd.microsoft.icon"/><link color="#000000" href="/images/ra_icon.svg" rel="mask-icon"/><script src="/bundles/default-js?v=3qaUNnKRH_PXCPLvCCsp5HpmkPv6G-3JQuMc2B329WA1"></script>
# <script>
# 	    googletag.cmd.push(function () { googletag.pubads().setTargeting("Page", "/events/uk/manchester").setTargeting("Category", "Listings").setTargeting("Section", "Events").setTargeting("Content", "EventsHome").setTargeting("Country", "UK").setTargeting("Area", "Manchester"); });
#          console.info('Interested in our code? Join us and help write it - https://www.residentadvisor.net/about/jobs');
#     </script>
# <script>
#             const widthTest = false;
#         if (window.screen.availWidth < 663 && window.screen.width < window.screen.height && !widthTest) {
#             document.write('<meta name="viewport" content="width=328">');
#         } else {
#             document.write('<meta name="viewport" content="width=device-width, initial-scale=1">');
#         }
#     </script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-940832047"></script>
# <script>
#             window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#             gtag('js', new Date());
#
#             gtag('config', 'AW-940832047');
#         </script>
# <script src="/js/dist/ReactLibs.bundle.js?636972463800438798"></script>
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                         'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                     })(window, document, 'script', 'dataLayer', 'GTM-M269WMP');
#         </script>
# </head>
# <body id="body">
# <input id="user-id" name="user-id" type="hidden" value="0"/>
# <input id="see-ngc" name="see-ngc" type="hidden" value="false"/>
# <a name="top"></a>
# <header id="header">
# <div class="pnlLeaderWrapper">
# <div id="pnlLeader">
# <aside class="div-gpt-ad-1452773484957-6 leader"><div class="ad" id="div-gpt-ad-1452773484957-6"></div></aside>
# </div>
# </div>
# <nav class="clearfix" id="user">
# <ul style="-moz-user-select: -moz-none; -khtml-user-select: none; -webkit-user-select: none;">
# <li class="but dark arrow-down" id="basket">
# Basket
# <div class="count basket" style="display:none;"><span></span></div>
# </li>
# <li class="but dark desktop-only desktop-wide-only" id="nav-link"><a href="https://www.doorsopen.co/#utm_source=RA&amp;utm_medium=Header-link" target="_blank"><span>Music Jobs</span></a></li>
# <li class="but arrow-down temp login" id="profile">Login / Register</li>
# </ul>
# </nav>
# <ul class="bbox panel" id="profile-panel">
# <li><a href="https://www.residentadvisor.net/login">Login</a></li>
# <li><a href="https://www.residentadvisor.net/register">Register</a></li>
# </ul>
# <div class="bbox panel bbox generic clearfix" id="basket-panel">
# <div class="items"></div><div class="basket-but but myra"></div>
# </div>
# <div class="notificationPanel bbox clearfix events col3" id="notificationPanel"></div><div class="null" id="navContainer">
# <div id="navbar">
# <div id="logo"><a class="icon" href="/">Resident Advisor</a></div>
# <div class="modal-full-screen" id="search-bar">
# <span class="modal-close">×</span>
# <div class="modal-body" id="search-bar-internal">
# <span class="f24 mobile-only search-header">Search</span>
# <div id="search-box-div">
# <input id="search-box" placeholder="Artists, Clubs, Promoters, Cities" type="text"/>
# </div>
# <div class="but large" id="search-button">
# <a id="search" title="Search">Submit</a>
# </div>
# <div class="grey pt16 search-helper" style="display: none;">Did you mean</div>
# </div>
# </div>
# <nav class="modal-full-screen" id="nav" role="navigation">
# <div class="modal-close">×</div>
# <ul class="modal-body open" data-display="0" id="links">
# <li class="mobile-only tablet-off">
# <div id="logo-modal-nav">
# <a class="icon" ga-event-action="RA-Logo" ga-event-category="nav" ga-on="click" href="/">Resident Advisor</a>
# </div>
# </li>
# <li id="mMagazine">
# <span>
# Magazine</span>
# <ul>
# <li id="mNews"><a ga-event-action="News" ga-event-category="nav" ga-on="click" href="/news">
# News</a></li>
# <li id="mReviews"><a ga-event-action="Reviews" ga-event-category="nav" ga-on="click" href="/reviews.aspx">
# Reviews</a></li>
# <li id="mFeatures"><a ga-event-action="Features" ga-event-category="nav" ga-on="click" href="/features.aspx">
# Features</a></li>
# <li id="mFilms"><a ga-event-action="Videos" ga-event-category="nav" ga-on="click" href="/videos">
# Videos</a></li>
# </ul>
# </li>
# <li data-selected="1" id="mListings">
# <span>
# Listings</span>
# <ul>
# <li data-selected="1" id="mEvents"><a ga-event-action="Events" ga-event-category="nav" ga-on="click" href="/events">
# Events</a></li>
# <li id="mClubs"><a ga-event-action="Clubs" ga-event-category="nav" ga-on="click" href="/clubs.aspx">
# Clubs</a></li>
# <li id="mFestivals"><a ga-event-action="Festivals" ga-event-category="nav" ga-on="click" href="/festivals.aspx">
# Festivals</a></li>
# <li id="mPhotos"><a ga-event-action="Photos" ga-event-category="nav" ga-on="click" href="/photos.aspx">
# Photos</a></li>
# </ul>
# </li>
# <li id="mMusic">
# <span>
# Music</span>
# <ul>
# <li id="mDjpages"><a ga-event-action="Artists" ga-event-category="nav" ga-on="click" href="/dj.aspx">
# Artists</a></li>
# <li id="mNewTracks"><a ga-event-action="New Tracks" ga-event-category="nav" ga-on="click" href="/tracks">
# New Tracks</a></li>
# <li id="mCharts"><a ga-event-action="DJ Charts" ga-event-category="nav" ga-on="click" href="/dj-charts.aspx">
#  DJ Charts</a></li>
# <li id="mPodcast"><a ga-event-action="Podcasts" ga-event-category="nav" ga-on="click" href="/podcast.aspx">
# Podcasts</a></li>
# </ul>
# </li>
# <li data-url="https://search.residentadvisor.net/" id="mSearch">
# <a ga-event-action="reveal-desktop" ga-event-category="search" ga-on="click" href="#">
# Search</a>
# </li>
# </ul>
# </nav>
# <div ga-event-action="burger" ga-event-category="nav" ga-on="click" id="but-links">
# <div class="icon"></div>
# </div>
# <div ga-event-action="mobile-reveal" ga-event-category="search" ga-on="click" id="but-search">
# <div class="icon"></div>
# </div>
# </div>
# <div class="add-space" id="sectionHead">
# <h1>Events</h1>
# </div>
# <link href="/bundles/autocomplete-css?v=LgsUcPmpTNV0nNOC1wz8x1BB-Dw1HtLyGXWG1QRD1nI1" rel="stylesheet"/>
# <script src="/bundles/autocomplete?v=ZaD3FsIAqm6cR8-cMvNrJ7huX4XQXQabm7PU9q5BgWY1"></script>
# <script src="/bundles/analytics-js?v=GRbOA-5b5S00wbAK8zMczxQRPgbblgKCy7f2bir0h281"></script>
# </div>
# <section class="clearfix" id="subnav">
# <ul>
# <li class="on" id="subnav-all"><a href="/events">All</a></li><li id="subnav-new"><a href="/events/new">New</a></li><li id="subnav-for-you"><a href="/events/favourites">For You</a></li><li id="subnav-promoters"><a href="/promoters.aspx">Promoters</a></li><li id="subnav-submit-an-event"><a href="/submit-event.aspx">Submit an event</a></li>
# </ul>
# </section>
# </header>
# <form action="./events" id="Form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="kV6+vJT05SW8oIOMuHgmGH8t8SxajzdMYzZos8GUN10SMY2roy+jW/QodI/M34qyi2H7tVbDw/GlqdygjqXTx/MBvOw="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="ADA4D364"/>
# </div>
# <main>
# <script src="/bundles/sticky-js?v=v676-NN9nrtj1Xpc3-lLALpuQvn14WLF-0HBUTbxEIQ1"></script>
# <script>
#     $(document).ready(function() {
#         $('.slide')
#         .scrollSnap({
#             page: 'eventshome'
#         });
#     })
#     </script>
# <ul class="content-list events-border">
# <li class="alt nobreak">
# <section class="content clearfix">
# <h1 class="listing-heading heading">Popular events in Manchester</h1>
# <div class="strip slide small" data-type="events" id="events-listing">
# <ul class="list small clearfix popular" style="padding: 0;">
# <li class="">
# <article class="highlight-top">
# <p>Fri, 28 Jun 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1260365"><img class="nohide" src="/images/events/flyer/2019/6/uk-0628-1260365-list.jpg"/></a>
# <p class="counter nohide">
# <span>32</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1260365">
# <h1>
# Making Faces with DEBONAIR/Jon K/12th Isle/Godspeed You Peter Andre
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=112509">The White Hotel</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 13 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1180978"><img class="nohide" src="/images/events/flyer/2019/7/uk-0713-1180978-list.jpg"/></a>
# <p class="counter nohide">
# <span>246</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1180978">
# <h1>
# Sankeys25: The 25th Anniversary Festival
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=55041">Bowlers Exhibition Centre</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 13 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1241543"><img class="nohide" src="/images/events/flyer/2019/6/uk-0613-1241543-list.jpg"/></a>
# <p class="counter nohide">
# <span>142</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1241543">
# <h1>
# Andrew Weatherall [all-night]
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=112509">The White Hotel</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 19 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1266331"><img class="nohide" src="/images/events/flyer/2019/7/uk-0719-1266331-list.jpg"/></a>
# <p class="counter nohide">
# <span>29</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1266331">
# <h1>
# HMS High Emotion Boat Party
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=168872">Dry Barge</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Fri, 26 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1261308"><img class="nohide" src="/images/events/flyer/2019/7/uk-0726-1261308-list.jpg"/></a>
# <p class="counter nohide">
# <span>46</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1261308">
# <h1>
# Hospital Productions [at] The White Hotel (PT1)
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=112509">The White Hotel</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 27 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1277360"><img class="nohide" src="/images/events/flyer/2019/7/uk-0727-1277360-list.jpg"/></a>
# <p class="counter nohide">
# <span>63</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1277360">
# <h1>
# Ordinary Friends presents Call Super
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=112509">The White Hotel</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 27 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1278667"><img class="nohide" src="/images/events/flyer/2019/7/uk-0727-1278667-list.jpg"/></a>
# <p class="counter nohide">
# <span>51</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1278667">
# <h1>
# Joy Orbison / Rahim / Lyster
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=14042">Soup Kitchen</a>
# </p>
# </article>
# </li><li class="">
# <article class="highlight-top">
# <p>Sat, 27 Jul 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1274753"><img class="nohide" src="/images/events/flyer/2019/7/uk-0727-1274753-list.jpg"/></a>
# <p class="counter nohide">
# <span>31</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1274753">
# <h1>
# Supernature Does Saturday
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=31626">The Retro Bar</a>
# </p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a></a>
# </div>
# <script>
#                             googleAnalytics.sendEventDataOnLoad('events-page', 'popular-events-loaded');
#                        </script>
# </section>
# <section class="iOSOnly content">
# <ul class="phones">
# <li class="f12 pb4 grey">Want RA listings on your mobile?</li>
# <li>
# <div class="but"><a href="https://itunes.apple.com/app/apple-store/id981952703?mt=8">Download the RA Guide</a></div>
# </li>
# </ul>
# </section>
# <div class="banner clearfix">
# <div id="pnlECTOSlot1" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-0"></div>
# </div>
# </div>
# </li>
# <li class="clearfix pt1">
# <div class="page-items content" id="previous-next">
# <ul>
# <li class="but arrow-left left" id="liPrevious">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/uk/manchester/week/2019-06-21">Previous </a>
# </li><li class="but arrow-right right" id="liNext">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/uk/manchester/week/2019-07-05">Next </a>
# </li>
# </ul>
# </div>
# <div class="content clearfix">
# <div class="plus8">
# <div>
# <script src="/bundles/area-country-date-filter-js?v=Q02f5CsIXWPDeOtgJVocYJrwjcQrf96m1qneHFerLLA1"></script>
# <ul class="clearfix classic" data-enableevent="True" id="ulButtons">
# <li class="but arrow-down right" id="liCountry">
# <input id="hdnCountryId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnCountryId" type="hidden" value="3"/>
# <span>UK</span><input id="country-name" type="hidden" value="United Kingdom"/><ul class="links" style="display: none;"><li data-id="7"><a href="/events">Canada</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="20"><a href="/events">Italy</a></li><li data-id="6"><a href="/events">Netherlands</a></li><li data-id="5"><a href="/events">Spain</a></li><li class="selected" data-id="3"><a href="/events">United Kingdom</a></li><li data-id="2"><a href="/events">United States of America</a></li><li data-id="0"><a href="/events">------------</a></li><li data-id="99"><a href="/events">Albania</a></li><li data-id="125"><a href="/events">Algeria</a></li><li data-id="113"><a href="/events">Andorra</a></li><li data-id="127"><a href="/events">Angola</a></li><li data-id="140"><a href="/events">Antigua and Barbuda</a></li><li data-id="16"><a href="/events">Argentina</a></li><li data-id="106"><a href="/events">Armenia</a></li><li data-id="1"><a href="/events">Australia</a></li><li data-id="57"><a href="/events">Austria</a></li><li data-id="108"><a href="/events">Azerbaijan</a></li><li data-id="117"><a href="/events">Bahamas</a></li><li data-id="80"><a href="/events">Bahrain</a></li><li data-id="107"><a href="/events">Bangladesh</a></li><li data-id="73"><a href="/events">Barbados</a></li><li data-id="76"><a href="/events">Belarus</a></li><li data-id="29"><a href="/events">Belgium</a></li><li data-id="34"><a href="/events">Belize</a></li><li data-id="141"><a href="/events">Benin</a></li><li data-id="126"><a href="/events">Bermuda</a></li><li data-id="142"><a href="/events">Bhutan</a></li><li data-id="85"><a href="/events">Bolivia</a></li><li data-id="74"><a href="/events">Bosnia and Herzegovina</a></li><li data-id="143"><a href="/events">Botswana</a></li><li data-id="28"><a href="/events">Brazil</a></li><li data-id="47"><a href="/events">Bulgaria</a></li><li data-id="144"><a href="/events">Burkina Faso</a></li><li data-id="110"><a href="/events">Cambodia</a></li><li data-id="145"><a href="/events">Cameroon</a></li><li data-id="7"><a href="/events">Canada</a></li><li data-id="92"><a href="/events">Cayman Islands</a></li><li data-id="25"><a href="/events">Chile</a></li><li data-id="30"><a href="/events">China</a></li><li data-id="59"><a href="/events">Colombia</a></li><li data-id="10"><a href="/events">Costa Rica</a></li><li data-id="146"><a href="/events">Cote d'Ivoire</a></li><li data-id="46"><a href="/events">Croatia</a></li><li data-id="102"><a href="/events">Cuba</a></li><li data-id="129"><a href="/events">Curacao</a></li><li data-id="82"><a href="/events">Cyprus</a></li><li data-id="49"><a href="/events">Czech Republic</a></li><li data-id="147"><a href="/events">Democratic Republic of the Congo</a></li><li data-id="51"><a href="/events">Denmark</a></li><li data-id="66"><a href="/events">Dominican Republic</a></li><li data-id="72"><a href="/events">Ecuador</a></li><li data-id="48"><a href="/events">Egypt</a></li><li data-id="54"><a href="/events">El Salvador</a></li><li data-id="71"><a href="/events">Estonia</a></li><li data-id="41"><a href="/events">Finland</a></li><li data-id="15"><a href="/events">France</a></li><li data-id="148"><a href="/events">Gambia</a></li><li data-id="75"><a href="/events">Georgia</a></li><li data-id="12"><a href="/events">Germany</a></li><li data-id="149"><a href="/events">Ghana</a></li><li data-id="103"><a href="/events">Gibraltar</a></li><li data-id="13"><a href="/events">Greece</a></li><li data-id="116"><a href="/events">Guam</a></li><li data-id="87"><a href="/events">Guatemala</a></li><li data-id="63"><a href="/events">Honduras</a></li><li data-id="39"><a href="/events">Hungary</a></li><li data-id="86"><a href="/events">Iceland</a></li><li data-id="58"><a href="/events">India</a></li><li data-id="37"><a href="/events">Indonesia</a></li><li data-id="91"><a href="/events">Iran</a></li><li data-id="14"><a href="/events">Ireland</a></li><li data-id ...
# </li>
# <li class="but arrow-down right" id="liArea">
# <input id="btnArea" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$btnArea" style="display:none;" type="submit" value="">
# <input id="hdnAreaId" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnAreaId" type="hidden" value="344"/>
# <span>Manchester</span><ul class="links" style="display: none;"><li class="parent" data-id="13"><a href="/events">London</a></li><li class="parent" data-id="14"><a href="/events">Midlands</a></li><li class="parent" data-id="16"><a href="/events">North</a></li><li data-id="346"><a href="/events">   Leeds</a></li><li data-id="343"><a href="/events">   Liverpool</a></li><li class="selected" data-id="344"><a href="/events">   Manchester</a></li><li data-id="345"><a href="/events">   Newcastle</a></li><li class="parent" data-id="35"><a href="/events">Northern Ireland</a></li><li class="parent" data-id="30"><a href="/events">Scotland</a></li><li data-id="342"><a href="/events">   Aberdeen</a></li><li data-id="341"><a href="/events">   Edinburgh</a></li><li data-id="340"><a href="/events">   Glasgow</a></li><li class="parent" data-id="15"><a href="/events">South + East</a></li><li class="parent" data-id="24"><a href="/events">West + Wales</a></li><li data-id="446"><a href="/events">   Bristol</a></li></ul>
# </input></li>
# <li class="but arrow-down right" id="liDate">
# <input id="btnDateRange" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$btnDateRange" style="display:none;" type="submit" value=""/>
# <input id="hdnDateRange" name="ctl00$ctl00$cphContent$_contentmain$ucAreaCountryDateFilter$hdnDateRange" type="hidden" value="2"/>
# <span data-id="2">By week</span><ul class="links" style="display: none;"><li data-id="1"><a href="/events/uk/manchester/default/0-0-0">By day</a></li><li class="selected" data-id="2"><a href="/events/uk/manchester/default/0-0-0">By week</a></li><li data-id="3"><a href="/events/uk/manchester/default/0-0-0">By month</a></li></ul>
# </li>
# </ul>
# </div>
# <div class="fl col4" id="event-listing">
# <ul class="list" id="items">
# <li><p class="eventDate date"><a href="/events.aspx?ai=344&amp;v=day&amp;mn=6&amp;yr=2019&amp;dy=28"><span>Fri, 28 Jun 2019 /</span></a></p></li><li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1260365#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1260365"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1260365-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1260365" itemprop="url" title="Event details of Making Faces with DEBONAIR/Jon K/12th Isle/Godspeed You Peter Andre">Making Faces with DEBONAIR/Jon K/12th Isle/Godspeed You Peter Andre</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1><div class="grey event-lineup">DEBONAIR, Jon K, 12th Isle, Godspeed you Peter Andre</div><p class="attending"><span>32</span> Attending</p></div></article></li><li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1274586#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1274586"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1274586-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1274586" itemprop="url" title="Event details of Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre">Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1><div class="grey event-lineup">Rabit, Maxwell Sterling, Croww, Acre</div><p class="attending"><span>21</span> Attending</p></div></article></li><li class=""><article class="event-item pick clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1271339#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1271339"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1271339-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1271339" itemprop="url" title="Event details of Soup Kitchen presents: Anthony Naples, Dj'j, Eszaid &amp; Cyrus">Soup Kitchen presents: Anthony Naples, Dj'j, Eszaid &amp; Cyrus</a> <span>at <a href="/club.aspx?id=14042">Soup Kitchen</a></span></h1><div class="grey event-lineup">Anthony Naples, DJ'J, Eszaid, Cyrus</div><p class="attending"><span>7</span> Attending</p><div class="pick-intro"><div class="pick-icon">RA Pick</div>Anthony Naples is one of the most exciting names out of the New York scene. He returns to Soup Kitchen with Incienso cofounder DJ J. </div></div></article></li><li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1262663#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1262663"><img height="76" src="/images/events/flyer/dj/blashaallatt-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary" ...
# </ul>
# </div>
# <div class="fl col2" style="padding-top: 88px;">
# <div class="pr8 sticky">
# <section id="calendar">
# <div class="h-align">
# <h1 class="heading">Calendar</h1>
# </div>
# <div id="calendar-inner">
# <select id="ddlCalendarMonth" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarMonth" style="width:104px;">
# <option value="12">December</option>
# <option value="11">November</option>
# <option value="10">October</option>
# <option value="9">September</option>
# <option value="8">August</option>
# <option value="7">July</option>
# <option selected="selected" value="6">June</option>
# <option value="5">May</option>
# <option value="4">April</option>
# <option value="3">March</option>
# <option value="2">February</option>
# <option value="1">January</option>
# </select>
# <select id="ddlCalendarYear" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarYear">
# <option selected="selected" value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# <option value="2011">2011</option>
# <option value="2010">2010</option>
# <option value="2009">2009</option>
# <option value="2008">2008</option>
# <option value="2007">2007</option>
# <option value="2006">2006</option>
# <option value="2005">2005</option>
# <option value="2004">2004</option>
# <option value="2003">2003</option>
# <option value="2002">2002</option>
# <option value="2001">2001</option>
# </select>
# <select id="ddlCalendarType" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$ddlCalendarType" style="width:104px;">
# <option value="day">By day</option>
# <option selected="selected" value="week">By week</option>
# <option value="month">By month</option>
# </select>
# <input id="hfCalendarDayOfWeek" name="ctl00$ctl00$cphContent$_contentmain$ucCalendar$hfCalendarDayOfWeek" type="hidden" value="28"/>
# <table><tr><th>Sun</th><th>Mon</th><th>Tue</th><th>Wed</th><th>Thu</th><th>Fri</th><th>Sat</th></tr><tr><td><a class="day-off" href="/events/uk/manchester/week/2019-05-26">26</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-05-27">27</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-05-28">28</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-05-29">29</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-05-30">30</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-05-31">31</a></td><td><a href="/events/uk/manchester/week/2019-06-01">1</a></td></tr><tr><td><a href="/events/uk/manchester/week/2019-06-02">2</a></td><td><a href="/events/uk/manchester/week/2019-06-03">3</a></td><td><a href="/events/uk/manchester/week/2019-06-04">4</a></td><td><a href="/events/uk/manchester/week/2019-06-05">5</a></td><td><a href="/events/uk/manchester/week/2019-06-06">6</a></td><td><a href="/events/uk/manchester/week/2019-06-07">7</a></td><td><a href="/events/uk/manchester/week/2019-06-08">8</a></td></tr><tr><td><a href="/events/uk/manchester/week/2019-06-09">9</a></td><td><a href="/events/uk/manchester/week/2019-06-10">10</a></td><td><a href="/events/uk/manchester/week/2019-06-11">11</a></td><td><a href="/events/uk/manchester/week/2019-06-12">12</a></td><td><a href="/events/uk/manchester/week/2019-06-13">13</a></td><td><a href="/events/uk/manchester/week/2019-06-14">14</a></td><td><a href="/events/uk/manchester/week/2019-06-15">15</a></td></tr><tr><td><a href="/events/uk/manchester/week/2019-06-16">16</a></td><td><a href="/events/uk/manchester/week/2019-06-17">17</a></td><td><a href="/events/uk/manchester/week/2019-06-18">18</a></td><td><a href="/events/uk/manchester/week/2019-06-19">19</a></td><td><a href="/events/uk/manchester/week/2019-06-20">20</a></td><td><a href="/events/uk/manchester/week/2019-06-21">21</a></td><td><a href="/events/uk/manchester/week/2019-06-22">22</a></td></tr><tr><td><a href="/events/uk/manchester/week/2019-06-23">23</a></td><td><a href="/events/uk/manchester/week/2019-06-24">24</a></td><td><a href="/events/uk/manchester/week/2019-06-25">25</a></td><td><a href="/events/uk/manchester/week/2019-06-26">26</a></td><td><a href="/events/uk/manchester/week/2019-06-27">27</a></td><td><span class="day-current">28</span></td><td><a href="/events/uk/manchester/week/2019-06-29">29</a></td></tr><tr><td><a href="/events/uk/manchester/week/2019-06-30">30</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-07-01">1</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-07-02">2</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-07-03">3</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-07-04">4</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-07-05">5</a></td><td><a class="day-off" href="/events/uk/manchester/week/2019-07-06">6</a></td></tr></table>
# </div>
# <script type="text/javascript">
# 		$("#ddlCalendarMonth, #ddlCalendarYear, #ddlCalendarType").change(function () {
#             var aSearch = location.search.indexOf("&") > 0
#                 ? location.search.split('&')
#                 : "";
#
# 			var sQueryString;
#
#             var month = $('#ddlCalendarMonth').val().length === 2
#                 ? $('#ddlCalendarMonth').val()
#                 : "0" + $('#ddlCalendarMonth').val();
#
#             var day = $('#hfCalendarDayOfWeek').val().length === 2
#                 ? $('#hfCalendarDayOfWeek').val()
#                 : "0" + $('#hfCalendarDayOfWeek').val();
#
#             var area = $('#liArea span').text().replace(/[^A-Z0-9]/ig, '').toLowerCase() === 'all'
#                 ? ""
#                 : $('#liArea span').text().replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/";
#
#             var country = area === ''
#                 ? $('#country-name').val()
#                 : $('#liCountry span').text()
#
# 			sQueryString = "/events/"
#                 + country.replace(/[^A-Z0-9]/ig, '').toLowerCase() + "/"
#                 + area
#                 + $('#ddlCalendarType').val() + "/"
# 				+ $('#ddlCalendarYear').val() + "-"
#                 + month + "-"
# 				+ day;
#
# 			location.href = sQueryString;
# 		});
# 	</script>
# </section>
# <div class="banner">
# <div id="pnlMPU">
# <div class="ad" id="div-gpt-ad-1452773484957-7" style="width: 300px; min-height: 250px; padding-bottom: 10px;"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="fl col2 h-align-toplist">
# <div class="mr8">
# <div class="newsletterEditorial">
# <h1 class="heading">Weekend highlights</h1>
# <img id="imgNewsletterEditorialImage" src="/images/email/local/13713-nor-1906.4.jpg"/>
# <div class="grey pb4">
# Anthony Naples
# </div>
# <span>
# Anthony Naples is one of the most innovative, exciting artists to come out of the current New York scene. Following the release of his latest album, <a href="/reviews/23854"><i>Fog FM</i></a>, he returns to Manchester's <a href="https://www.residentadvisor.net/events/1271339">Soup Kitchen</a> with his Incienso label cofounder DJ J.</span>
# </div>
# <section class="top-list generic events" id="toplist">
# <h1 class="heading">Top Manchester clubs</h1>
# <ul>
# <li><a ga-event-action="The Warehouse Project" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=61049">The Warehouse Project</a> /</li><li><a ga-event-action="Soup Kitchen" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=14042">Soup Kitchen</a> /</li><li><a ga-event-action="Piccadilly Train Station" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=5684">Piccadilly Train Station</a> /</li><li><a ga-event-action="Joshua Brooks" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=12513">Joshua Brooks</a> /</li><li><a ga-event-action="Hidden" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=81697">Hidden</a> /</li><li><a ga-event-action="The White Hotel" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=112509">The White Hotel</a> /</li><li><a ga-event-action="Gorilla" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=68271">Gorilla</a> /</li><li><a ga-event-action="Albert Hall" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=85781">Albert Hall</a> /</li><li><a ga-event-action="The Deaf Institute" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=9958">The Deaf Institute</a> /</li><li><a ga-event-action="Antwerp Mansion" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=29916">Antwerp Mansion</a> /</li><li><a ga-event-action="Spektrum" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=12604">Spektrum</a> /</li><li><a ga-event-action="Islington Mill" ga-event-category="top-clubs" ga-on="click" href="/club.aspx?id=5952">Islington Mill</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-clubs" ga-on="click" href="/clubs.aspx?ai=344">More Manchester clubs</a></div>
# </section><section class="top-list generic events" id="toplist">
# <h1 class="heading">Top 20 regions</h1>
# <ul>
# <li><a ga-event-action="London" ga-event-category="top-regions" ga-on="click" href="/guide/uk/london">London, UK</a> /</li><li><a ga-event-action="Ibiza" ga-event-category="top-regions" ga-on="click" href="/guide/es/ibiza">Ibiza, ES</a> /</li><li><a ga-event-action="Berlin" ga-event-category="top-regions" ga-on="click" href="/guide/de/berlin">Berlin, DE</a> /</li><li><a ga-event-action="New York" ga-event-category="top-regions" ga-on="click" href="/guide/us/newyork">New York, US</a> /</li><li><a ga-event-action="Barcelona" ga-event-category="top-regions" ga-on="click" href="/guide/es/barcelona">Barcelona, ES</a> /</li><li><a ga-event-action="Amsterdam" ga-event-category="top-regions" ga-on="click" href="/guide/nl/amsterdam">Amsterdam, NL</a> /</li><li><a ga-event-action="Tokyo" ga-event-category="top-regions" ga-on="click" href="/guide/jp/tokyo">Tokyo, JP</a> /</li><li><a ga-event-action="Paris" ga-event-category="top-regions" ga-on="click" href="/guide/fr/paris">Paris, FR</a> /</li><li><a ga-event-action="Los Angeles" ga-event-category="top-regions" ga-on="click" href="/guide/us/losangeles">Los Angeles, US</a> /</li><li><a ga-event-action="South + East" ga-event-category="top-regions" ga-on="click" href="/guide/uk/southeast">South + East, UK</a> /</li><li><a ga-event-action="Miami" ga-event-category="top-regions" ga-on="click" href="/guide/us/miami">Miami, US</a> /</li><li><a ga-event-action="San Francisco" ga-event-category="top-regions" ga-on="click" href="/guide/us/sanfrancisco">San Francisco, US</a> /</li><li><a ga-event-action="Melbourne" ga-event-category="top-regions" ga-on="click" href="/guide/au/melbourne">Melbourne, AU</a> /</li><li><a ga-event-action="Manchester" ga-event-category="top-regions" ga-on="click" href="/guide/uk/manchester">Manchester, UK</a> /</li><li><a ga-event-action="Chicago" ga-event-category="top-regions" ga-on="click" href="/guide/us/chicago">Chicago, US</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/croatia">Croatia</a> /</li><li><a ga-event-action="Montreal" ga-event-category="top-regions" ga-on="click" href="/guide/ca/montreal">Montreal, CA</a> /</li><li><a ga-event-action="Glasgow" ga-event-category="top-regions" ga-on="click" href="/guide/uk/glasgow">Glasgow, UK</a> /</li><li><a ga-event-action="Madrid" ga-event-category="top-regions" ga-on="click" href="/guide/es/madrid">Madrid, ES</a> /</li><li><a ga-event-action="All" ga-event-category="top-regions" ga-on="click" href="/guide/greece">Greece</a> /</li>
# </ul>
# <div class="but"><a ga-event-action="see-more" ga-event-category="top-regions" ga-on="click" href="/events.aspx?show=all">More regions</a></div>
# </section><div id="pnlSkyscraper">
# <div class="ad mobile-off" id="div-gpt-ad-1452773484957-12" style="width: 160px; height: 600px;"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-items content sub clearfix">
# <ul>
# <li class="but arrow-left left" id="liPrevious2">
# <a ga-event-action="Previous " ga-event-category="event-listings" ga-on="click" href="/events/uk/manchester/week/2019-06-21">Previous </a>
# </li><li class="but arrow-right right" id="liNext2">
# <a ga-event-action="Next " ga-event-category="event-listings" ga-on="click" href="/events/uk/manchester/week/2019-07-05">Next </a>
# </li>
# </ul>
# </div>
# <div class="banner clearfix">
# <div id="pnlECTOSlot2" style="text-align: center;">
# <div class="ad" id="div-gpt-ad-1452773484957-1"></div>
# </div>
# </div>
# <br/>
# <span>01 /</span>
# </li>
# <li class="alt">
# <section class="content" id="popular-news">
# <h1 class="heading listing-heading">Most popular news</h1>
# <div class="but heading-more mobile-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# <div class="strip small slide" data-type="news" id="news-listing">
# <ul class="list">
# <li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 24 Jun 2019</p>
# <a href="/news/43993">
# <img class="thumb" src="/images/news/2019/autechre-warp-tapes-89-93-free-download.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43993/?comments=1">Post a comment</a>
# </p><a href="/news/43993">
# <h1>Autechre give away unreleased Warp Tapes 89-93 as free download</h1>
# </a>
# <p class="copy">The two hours of archival music were originally broadcast on NTS this past weekend.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Jun 2019</p>
# <a href="/news/44007">
# <img class="thumb" src="/images/news/2019/concrete-paris-closing-club.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44007/?comments=1">Post a comment</a>
# </p><a href="/news/44007">
# <h1>Paris's Concrete nightclub is closing</h1>
# </a>
# <p class="copy">The popular venue's final party will take place on the weekend of July 20th.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 21 Jun 2019</p>
# <a href="/news/43985">
# <img class="thumb" src="/images/news/2019/scan-7.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43985/?comments=1">Post a comment</a>
# </p><a href="/news/43985">
# <h1>Detroit collective Scan 7 announces first album in 20 years</h1>
# </a>
# <p class="copy">Between Worlds is out on Deeptrax Records in July.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Jun 2019</p>
# <a href="/news/43995">
# <img class="thumb" src="/images/news/2019/warehouse-project-mayfield-depot-manchester-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43995/?comments=1">Post a comment</a>
# </p><a href="/news/43995">
# <h1>The Warehouse Project to inaugurate residency at new home, Depot, with Aphex Twin</h1>
# </a>
# <p class="copy">Nina Kraviz, Skepta, Disclosure, Skream and Marco Carola are among the other artists booked across seven dates this fall.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Fri, 21 Jun 2019</p>
# <a href="/news/43989">
# <img class="thumb" src="/images/news/2019/call-super-ondo-fudd-troilogy-tapes-eyes-glide-oxide-ep-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43989/?comments=1">Post a comment</a>
# </p><a href="/news/43989">
# <h1>Call Super reveals new Ondo Fudd EP on The Trilogy Tapes</h1>
# </a>
# <p class="copy">Eyes Glide Through The Oxide is the final part in his trilogy for the London label.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 24 Jun 2019</p>
# <a href="/news/43990">
# <img class="thumb" src="/images/news/2019/floating-points-far-away.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43990/?comments=1">Post a comment</a>
# </p><a href="/news/43990">
# <h1>Floating Points releases double-cassette live mix</h1>
# </a>
# <p class="copy">The two-hour mix cassette was recorded live at Far Away in Los Angeles.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Jun 2019</p>
# <a href="/news/44003">
# <img class="thumb" src="/images/news/2019/jeff-mills-press-shot.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44003/?comments=1">Post a comment</a>
# </p><a href="/news/44003">
# <h1>Jeff Mills reveals new album, Moon - The Area Of Influence, for Axis Records</h1>
# </a>
# <p class="copy">The LP commemorates the 50th anniversary of the moon landing.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Jun 2019</p>
# <a href="/news/44010">
# <img class="thumb" src="/images/news/2019/ade-2019-lineup.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44010/?comments=1">Post a comment</a>
# </p><a href="/news/44010">
# <h1>Amsterdam Dance Event reveals first names for 2019</h1>
# </a>
# <p class="copy">Helena Hauff, Jeff Mills, Amelie Lens, SOPHIE and DJ Nobu are among the first wave to play the 24th edition this October.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Jun 2019</p>
# <a href="/news/44001">
# <img class="thumb" src="/images/news/2019/schenk-hague-closing.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44001/?comments=1">Post a comment</a>
# </p><a href="/news/44001">
# <h1>Schenk, a former atomic bunker housing offices, studio space and a radio station in The Hague, forced to close</h1>
# </a>
# <p class="copy">I-F, Syncom Data and the Intergalactic FM station ONDERWERELD were all headquartered in the underground community hub.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Jun 2019</p>
# <a href="/news/43999">
# <img class="thumb" src="/images/news/2019/jayda-g-remix-series.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43999/?comments=1">Post a comment</a>
# </p><a href="/news/43999">
# <h1>Honey Dijon, Dâm-Funk and DJ Fett Burger remix Jayda G on new EP</h1>
# </a>
# <p class="copy">The 12-inch arrives on July 19th via Ninja Tune.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Jun 2019</p>
# <a href="/news/44014">
# <img class="thumb" src="/images/news/2019/radar-nightclub-melbourne-logo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44014/?comments=1">Post a comment</a>
# </p><a href="/news/44014">
# <h1>New Melbourne club Radar to open in place of Lounge</h1>
# </a>
# <p class="copy">The team behind Section 8 will open the space in July.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Jun 2019</p>
# <a href="/news/43996">
# <img class="thumb" src="/images/news/2019/ryan-elliott-faith-beat-01-the-introduction-press-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43996/?comments=1">Post a comment</a>
# </p><a href="/news/43996">
# <h1>Ryan Elliott launches label, Faith Beat, with new EP</h1>
# </a>
# <p class="copy">The imprint will release "techno, house and anything in between," with a particular focus on club tools.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Mon, 24 Jun 2019</p>
# <a href="/news/43992">
# <img class="thumb" src="/images/news/2019/off-sonar-2019.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43992/?comments=1">Post a comment</a>
# </p><a href="/news/43992">
# <h1>OFFSónar completes 2019 programme</h1>
# </a>
# <p class="copy">Luciano and Damian Lazarus will headline the Woomoon event on July 18th—plus, a handful of afterparties have been revealed.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Sun, 23 Jun 2019</p>
# <a href="/news/43980">
# <img class="thumb" src="/images/news/2019/siavash-amini-serus-room40-a-recollection-of-the-disappeared-press-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43980/?comments=1">Post a comment</a>
# </p><a href="/news/43980">
# <h1>Iranian artist Siavash Amini to release new EP, Serus, on Room40</h1>
# </a>
# <p class="copy">The record is "an ode to night, literal and metaphorical."</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Jun 2019</p>
# <a href="/news/44004">
# <img class="thumb" src="/images/news/2019/dozzy-new-ep-spazio.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44004/?comments=1">Post a comment</a>
# </p><a href="/news/44004">
# <h1>New Donato Dozzy EP, Variations, coming on Spazio Disponibile</h1>
# </a>
# <p class="copy">The Italian artist has also confirmed a new album is on the way in 2019.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Jun 2019</p>
# <a href="/news/43998">
# <img class="thumb" src="/images/news/2019/lolina-inga-copeland-who-is-experimental-music-photo.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43998/?comments=1">Post a comment</a>
# </p><a href="/news/43998">
# <h1>Lolina releases new album, Who Is Experimental Music?</h1>
# </a>
# <p class="copy">The six-track LP is out now on Bandcamp.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Jun 2019</p>
# <a href="/news/44013">
# <img class="thumb" src="/images/news/2019/brian-eno.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44013/?comments=1">Post a comment</a>
# </p><a href="/news/44013">
# <h1>An asteroid has been named after Brian Eno</h1>
# </a>
# <p class="copy">Asteroid 81948 will now be known as Eno.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Tue, 25 Jun 2019</p>
# <a href="/news/43997">
# <img class="thumb" src="/images/news/2019/oasis2018_0914_olliesimcock-3712.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/43997/?comments=1">Post a comment</a>
# </p><a href="/news/43997">
# <h1>Morocco's Oasis Festival completes lineup with Theo Parrish, Moodymann</h1>
# </a>
# <p class="copy">Hercules &amp; Love Affair, Anastasia Kristensen and Cassy &amp; Eats Everything back-to-back will also play this September in Marrakech.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Jun 2019</p>
# <a href="/news/44009">
# <img class="thumb" src="/images/news/2019/invisible_city_record_closed_storefront.jpeg"/>
# </a>
# <p class="comments light">
# <a href="/news/44009/?comments=1">Post a comment</a>
# </p><a href="/news/44009">
# <h1>Toronto record shop Invisible City closes physical storefront 'indefinitely'</h1>
# </a>
# <p class="copy">"We're looking for a new home now, and we hope to be back up and running soon," the owners say.</p>
# </article>
# </li><li class="min-height-medium">
# <article class="highlight-top">
# <p class="date">Wed, 26 Jun 2019</p>
# <a href="/news/44012">
# <img class="thumb" src="/images/news/2019/clark-kirivariation3-photocreditalmahaser.jpg"/>
# </a>
# <p class="comments light">
# <a href="/news/44012/?comments=1">Post a comment</a>
# </p><a href="/news/44012">
# <h1>Clark self-releases new album, Kiri Variations	</h1>
# </a>
# <p class="copy">Out in late July, it includes his "most song-based composition ever."</p>
# </article>
# </li> </ul>
# </div>
# <div class="link-more mobile-only tablet-off">
# <a ga-event-action="see-more" ga-event-category="news" ga-on="click" href="/news">More news</a>
# </div>
# </section>
# <span>02 /</span>
# </li>
# </ul>
# </main>
# </form>
# <footer class="clearfix"><ul class="content-list">
# <li>
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col2-3">
# <ul class="pb32">
# <li id="logo-footer"><a href="/">RA</a></li>
# <li class="f12 grey pt16">Copyright © 2019 Resident Advisor Ltd.</li>
# <li class="f12 grey">All rights reserved.</li>
# <li class="f12 grey"><a href="/privacy">Privacy</a> &amp; <a href="/terms">Terms</a></li>
# <li class="f12 grey"><a href="/cookiepolicy">Cookie Policy</a></li>
# </ul>
# </div>
# <div class="fl col4-5 pt60">
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Resident Advisor /</li> <li><a ga-event-action="about" ga-event-category="homefooter" ga-on="click" href="/about">About</a></li>
# <li><a ga-event-action="advertise" ga-event-category="homefooter" ga-on="click" href="/about/advertising">Advertise</a></li>
# <li><a ga-event-action="jobs" ga-event-category="homefooter" ga-on="click" href="https://www.doorsopen.co/company/12/resident-advisor/#utm_source=RA&amp;utm_medium=footer-link">Jobs</a></li>
# <li><a ga-event-action="raevents" ga-event-category="homefooter" ga-on="click" href="/features/3214">24/7</a></li>
# <li><br/></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">RA Tickets /</li>
# <li><a ga-event-action="mytickets" ga-event-category="homefooter" ga-on="click" href="/shop/history">My Tickets</a></li>
# <li><a ga-event-action="ticketfaq" ga-event-category="homefooter" ga-on="click" href="/shop/faq">Ticketing FAQ</a></li>
# <li><a ga-event-action="resale" ga-event-category="homefooter" ga-on="click" href="/tickets/resale">Resale</a></li>
# <li><a ga-event-action="selltickets" ga-event-category="homefooter" ga-on="click" href="/tickets">Sell tickets on RA</a></li>
# <li><div class="myra but" style="width: 152px; margin-top: 50px;"><a class="submit-event" ga-event-action="submitevent" ga-event-category="homefooter" ga-on="click" href="/submit-event.aspx">Submit event</a></div></li>
# <li><br/></li>
# </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Apps /</li> <li><a ga-event-action="raguide" ga-event-category="homefooter" ga-on="click" href="/ra-guide">RA Guide</a></li>
# <li><a ga-event-action="ticketscanner" ga-event-category="homefooter" ga-on="click" href="/tickets/scanner">RA Ticket Scanner</a></li> </ul>
# </div>
# <div class="fl col1 footer-category">
# <ul>
# <li class="f12 grey">Elsewhere /</li>
# <li><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/user/residentadvisor?sub_confirmation=1">Watch on YouTube</a></li>
# <li><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">Follow on Facebook</a></li>
# <li><a ga-event-action="raapplemusic" ga-event-category="homefooter" ga-on="click" href="https://itunes.apple.com/gb/curator/resident-advisor/id996091687">Listen on Apple Music</a></li>
# <li><a ga-event-action="raspotify" ga-event-category="homefooter" ga-on="click" href="https://open.spotify.com/user/residentadvisor">Stream on Spotify</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="nobreak">
# <div class="content clearfix">
# <div class="clearfix plus8">
# <div class="fl col3">
# <a href="https://jp.residentadvisor.net/"><a href="https://jp.residentadvisor.net/">RA is also available in Japanese. 日本版</a></a>
# </div>
# <ul class="col1p5" id="social">
# <li class="ytb"><a ga-event-action="rayoutube" ga-event-category="homefooter" ga-on="click" href="http://www.youtube.com/residentadvisor">RA on YouTube</a></li>
# <li class="fcb"><a ga-event-action="rafacebook" ga-event-category="homefooter" ga-on="click" href="http://www.facebook.com/residentadvisor">RA on Facebook</a></li>
# <li class="twt"><a ga-event-action="ratwitter" ga-event-category="homefooter" ga-on="click" href="http://www.twitter.com/residentadvisor">RA on Twitter</a></li>
# <li class="ins"><a ga-event-action="rainstagram" ga-event-category="homefooter" ga-on="click" href="http://instagram.com/resident_advisor">RA on Instagram</a></li>
# <li class="snd"><a ga-event-action="rasoundcloud" ga-event-category="homefooter" ga-on="click" href="http://www.soundcloud.com/resident-advisor">RA on Soundcloud</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul></footer>
# <script type="text/javascript">
#         (function(i, s, o, g, r, a, m) {
#                                         i['GoogleAnalyticsObject'] = r;
#                                         i[r] = i[r] || function() {
#                                             (i[r].q = i[r].q || []).push(arguments)
#                                         }, i[r].l = 1 * new Date();
#                                         a = s.createElement(o), m = s.getElementsByTagName(o)[0];
#                                         a.async = 1;
#                                         a.src = g;
#                                         m.parentNode.insertBefore(a, m)
#                                     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#                                     ga('create', 'UA-313318-1', 'residentadvisor.net'
#                                     );
#                                     ga('require', 'displayfeatures');
#                                     ga('send', 'pageview');
#                                     ga('require', 'eventTracker');
#
#         if (window.location.href.indexOf('.residentadvisor.net') >= 0 && window.location.pathname.indexOf('submit-event') === 0) {
# 	        (function(r, a, v, e, l, i, n) {
# 	            r[l] = r[l] || function() { (r[l].q = r[l].q || []).push(arguments) };
# 	            i = a.createElement(v);
# 	            i.async = i.defer = 1;
# 	            i.src = e;
# 	            a.body.appendChild(i)
# 	        })(window, document, 'script', 'https://cdn.ravelin.net/js/rvn-beta.min.js', 'ravelin');
# 	        ravelin('setApiKey', 'pk_live_Z6F2v32uJEQnwn46SLF7xdojmnOPLfAI');
#             ravelin('setCustomerId', '0');
#             ravelin('setCookieDomain', '.residentadvisor.net');
# 	    }
# 	</script>
# <script>
#         cssVars({})
#     </script>
# </body>
# </html>

# %%
event_listings = soup.findAll('h1')

# %%
event_listings
# Out:
# [<h1>Events</h1>,
#  <h1 class="listing-heading heading">Popular events in Manchester</h1>,
#  <h1>
#  Making Faces with DEBONAIR/Jon K/12th Isle/Godspeed You Peter Andre
#  </h1>,
#  <h1>
#  Sankeys25: The 25th Anniversary Festival
#  </h1>,
#  <h1>
#  Andrew Weatherall [all-night]
#  </h1>,
#  <h1>
#  HMS High Emotion Boat Party
#  </h1>,
#  <h1>
#  Hospital Productions [at] The White Hotel (PT1)
#  </h1>,
#  <h1>
#  Ordinary Friends presents Call Super
#  </h1>,
#  <h1>
#  Joy Orbison / Rahim / Lyster
#  </h1>,
#  <h1>
#  Supernature Does Saturday
#  </h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1260365" itemprop="url" title="Event details of Making Faces with DEBONAIR/Jon K/12th Isle/Godspeed You Peter Andre">Making Faces with DEBONAIR/Jon K/12th Isle/Godspeed You Peter Andre</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1274586" itemprop="url" title="Event details of Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre">Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1271339" itemprop="url" title="Event details of Soup Kitchen presents: Anthony Naples, Dj'j, Eszaid &amp; Cyrus">Soup Kitchen presents: Anthony Naples, Dj'j, Eszaid &amp; Cyrus</a> <span>at <a href="/club.aspx?id=14042">Soup Kitchen</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1262663" itemprop="url" title="Event details of Mixing Mates with Blasha &amp; Allatt [All Night Long]">Mixing Mates with Blasha &amp; Allatt [All Night Long]</a> <span>at <a href="/club.aspx?id=123363">Stage &amp; Radio</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1272524" itemprop="url" title="Event details of Radiance">Radiance</a> <span>at <a href="/club.aspx?id=23895">Aatma / Kraak Gallery</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1283296" itemprop="url" title="Event details of Drøne/diyd present: 'øde'- AUTUMNS, Kenny Campbell, Schoolhouse">Drøne/diyd present: 'øde'- AUTUMNS, Kenny Campbell, Schoolhouse</a> <span>at <a href="/club.aspx?id=158448">The Peer Hat</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1274459" itemprop="url" title="Event details of Bakk Heia Records Eastern Bloc Instore">Bakk Heia Records Eastern Bloc Instore</a> <span>at <a href="/club.aspx?id=61121">Eastern Bloc Records</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1283727" itemprop="url" title="Event details of Blend at the Pink Room">Blend at the Pink Room</a> <span>at <a href="/club.aspx?id=158509">Yes</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1283293" itemprop="url" title="Event details of Flight Mode">Flight Mode</a> <span>at <a href="/club.aspx?id=64706">South</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1274586" itemprop="url" title="Event details of Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre">Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1269771" itemprop="url" title="Event details of Night Shift">Night Shift</a> <span>at <a href="/club.aspx?id=168850">Tusk</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1249750" itemprop="url" title="Event details of Homoelectric presents Babyhomo">Homoelectric presents Babyhomo</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1278907" itemprop="url" title="Event details of Syntax_error with Frazer Shelton, Randle p Mcmurphy, Gary Sloan, Anthony Dobson">Syntax_error with Frazer Shelton, Randle p Mcmurphy, Gary Sloan, Anthony Dobson</a> <span>at <a href="/club.aspx?id=61121">Eastern Bloc Records</a></span></h1>,
#  <h1 class="event-title" itemprop="summary"><a href="/events/1282849" itemprop="url" title="Event details of Strange Riddims present: Hagan, Tamtam, Down2earth">Strange Riddims present: Hagan, Tamtam, Down2earth</a> <span>at <a href="/club.aspx?id=14042">Soup Kitchen</a></span></h1>,
#  <h1 class="heading">Calendar</h1>,
#  <h1 class="heading">Weekend highlights</h1>,
#  <h1 class="heading">Top Manchester clubs</h1>,
#  <h1 class="heading">Top 20 regions</h1>,
#  <h1 class="heading listing-heading">Most popular news</h1>,
#  <h1>Autechre give away unreleased Warp Tapes 89-93 as free download</h1>,
#  <h1>Paris's Concrete nightclub is closing</h1>,
#  <h1>Detroit collective Scan 7 announces first album in 20 years</h1>,
#  <h1>The Warehouse Project to inaugurate residency at new home, Depot, with Aphex Twin</h1>,
#  <h1>Call Super reveals new Ondo Fudd EP on The Trilogy Tapes</h1>,
#  <h1>Floating Points releases double-cassette live mix</h1>,
#  <h1>Jeff Mills reveals new album, Moon - The Area Of Influence, for Axis Records</h1>,
#  <h1>Amsterdam Dance Event reveals first names for 2019</h1>,
#  <h1>Schenk, a former atomic bunker housing offices, studio space and a radio station in The Hague, forced to close</h1>,
#  <h1>Honey Dijon, Dâm-Funk and DJ Fett Burger remix Jayda G on new EP</h1>,
#  <h1>New Melbourne club Radar to open in place of Lounge</h1>,
#  <h1>Ryan Elliott launches label, Faith Beat, with new EP</h1>,
#  <h1>OFFSónar completes 2019 programme</h1>,
#  <h1>Iranian artist Siavash Amini to release new EP, Serus, on Room40</h1>,
#  <h1>New Donato Dozzy EP, Variations, coming on Spazio Disponibile</h1>,
#  <h1>Lolina releases new album, Who Is Experimental Music?</h1>,
#  <h1>An asteroid has been named after Brian Eno</h1>,
#  <h1>Morocco's Oasis Festival completes lineup with Theo Parrish, Moodymann</h1>,
#  <h1>Toronto record shop Invisible City closes physical storefront 'indefinitely'</h1>,
#  <h1>Clark self-releases new album, Kiri Variations	</h1>]

# %%
event_listings.findAll(class_="title")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-f16d90f82a31> in <module>
# ----> 1 event_listings.findAll(class_="title")
#
# C:\Anaconda\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'findAll'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
#finding date
entries = event_listings.findAll('li')
entries
# Out:
# [<li><p class="eventDate date"><a href="/events.aspx?ai=344&amp;v=day&amp;mn=6&amp;yr=2019&amp;dy=28"><span>Fri, 28 Jun 2019 /</span></a></p></li>,
#  <li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1260365#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1260365"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1260365-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1260365" itemprop="url" title="Event details of Making Faces with DEBONAIR/Jon K/12th Isle/Godspeed You Peter Andre">Making Faces with DEBONAIR/Jon K/12th Isle/Godspeed You Peter Andre</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1><div class="grey event-lineup">DEBONAIR, Jon K, 12th Isle, Godspeed you Peter Andre</div><p class="attending"><span>32</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1274586#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1274586"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1274586-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1274586" itemprop="url" title="Event details of Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre">Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1><div class="grey event-lineup">Rabit, Maxwell Sterling, Croww, Acre</div><p class="attending"><span>21</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item pick clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1271339#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1271339"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1271339-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1271339" itemprop="url" title="Event details of Soup Kitchen presents: Anthony Naples, Dj'j, Eszaid &amp; Cyrus">Soup Kitchen presents: Anthony Naples, Dj'j, Eszaid &amp; Cyrus</a> <span>at <a href="/club.aspx?id=14042">Soup Kitchen</a></span></h1><div class="grey event-lineup">Anthony Naples, DJ'J, Eszaid, Cyrus</div><p class="attending"><span>7</span> Attending</p><div class="pick-intro"><div class="pick-icon">RA Pick</div>Anthony Naples is one of the most exciting names out of the New York scene. He returns to Soup Kitchen with Incienso cofounder DJ J. </div></div></article></li>,
#  <li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1262663#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1262663"><img height="76" src="/images/events/flyer/dj/blashaallatt-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1262663" itemprop="url" title="Event details of Mixing Mates with Blasha &amp; Allatt [All Night Long]">Mixing Mates with Blasha &amp; Allatt [All Night Long]</a> <span>at <a href="/club.aspx?id=123363">Stage &amp; Radio</a></span></h1><div class="grey event-lineup">Blasha &amp; Allatt, Leanne Ellinger, Roisin Walsh, Red Lab, WeeDot.</div><p class="attending"><span>4</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1272524"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1272524-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1272524" itemprop="url" title="Event details of Radiance">Radiance</a> <span>at <a href="/club.aspx?id=23895">Aatma / Kraak Gallery</a></span></h1><div class="grey event-lineup">Tony Bruno, Arondeus, Method</div><p class="attending"><span>2</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1283296"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1283296-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1283296" itemprop="url" title="Event details of Drøne/diyd present: 'øde'- AUTUMNS, Kenny Campbell, Schoolhouse">Drøne/diyd present: 'øde'- AUTUMNS, Kenny Campbell, Schoolhouse</a> <span>at <a href="/club.aspx?id=158448">The Peer Hat</a></span></h1><div class="grey event-lineup">Autumns, Kenny Campbell, Schoolhouse, Prangers, Adrian Steele</div><p class="attending"><span>2</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1274459"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1274459-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1274459" itemprop="url" title="Event details of Bakk Heia Records Eastern Bloc Instore">Bakk Heia Records Eastern Bloc Instore</a> <span>at <a href="/club.aspx?id=61121">Eastern Bloc Records</a></span></h1><div class="grey event-lineup">Schuttle, Jorg Kuning, Attic Salt, Hercules M, Bitzer Malo</div><p class="attending"><span>1</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><a href="/events/1283727"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1283727-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1283727" itemprop="url" title="Event details of Blend at the Pink Room">Blend at the Pink Room</a> <span>at <a href="/club.aspx?id=158509">Yes</a></span></h1><div class="grey event-lineup">Pablo Blanquito, Atike, Knohts</div><p class="attending"><span>1</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix small-item" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-28T00:00" itemprop="startDate">2019-06-28T00:00</time></span><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1283293" itemprop="url" title="Event details of Flight Mode">Flight Mode</a> <span>at <a href="/club.aspx?id=64706">South</a></span></h1></div></article></li>,
#  <li><div class="but myra mt16" style="width: 152px;"><a href="/submit-event.aspx?ai=344">Submit event</a></div></li>,
#  <li><p class="eventDate date"><a href="/events.aspx?ai=344&amp;v=day&amp;mn=6&amp;yr=2019&amp;dy=29"><span>Sat, 29 Jun 2019 /</span></a></p></li>,
#  <li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1274586#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-29T00:00" itemprop="startDate">2019-06-29T00:00</time></span><a href="/events/1274586"><img height="76" src="/images/events/flyer/2019/6/uk-0628-1274586-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1274586" itemprop="url" title="Event details of Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre">Transmute: Rabit &amp; Maxwell Sterling / Croww / Acre</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1><div class="grey event-lineup">Rabit, Maxwell Sterling, Croww, Acre</div><p class="attending"><span>21</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix tickets-bkg-logo" itemscope="" itemtype="http://data-vocabulary.org/Event"><a href="/events/1269771#tickets"><img class="nohide" src="https://residentadvisor.net/images/ra-tix.png" style="height: 23px; width: 40px; right: 0px; position: absolute; top: 1px;"/></a><span style="display:none;"><time datetime="2019-06-29T00:00" itemprop="startDate">2019-06-29T00:00</time></span><a href="/events/1269771"><img height="76" src="/images/events/flyer/2019/6/uk-0629-1269771-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1269771" itemprop="url" title="Event details of Night Shift">Night Shift</a> <span>at <a href="/club.aspx?id=168850">Tusk</a></span></h1><div class="grey event-lineup">Foxez Residents</div><p class="attending"><span>5</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-29T00:00" itemprop="startDate">2019-06-29T00:00</time></span><a href="/events/1249750"><img height="76" src="/images/events/flyer/2019/6/uk-0629-1249750-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1249750" itemprop="url" title="Event details of Homoelectric presents Babyhomo">Homoelectric presents Babyhomo</a> <span>at <a href="/club.aspx?id=112509">The White Hotel</a></span></h1><div class="grey event-lineup">Jamie Bull, Will TRAMP!, Gina Breeze</div><p class="attending"><span>6</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-29T00:00" itemprop="startDate">2019-06-29T00:00</time></span><a href="/events/1278907"><img height="76" src="/images/events/flyer/2019/6/uk-0629-1278907-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1278907" itemprop="url" title="Event details of Syntax_error with Frazer Shelton, Randle p Mcmurphy, Gary Sloan, Anthony Dobson">Syntax_error with Frazer Shelton, Randle p Mcmurphy, Gary Sloan, Anthony Dobson</a> <span>at <a href="/club.aspx?id=61121">Eastern Bloc Records</a></span></h1><div class="grey event-lineup">Frazer Shelton, Randle P McMurphy, Gary Sloan, Anthony Dobson</div><p class="attending"><span>2</span> Attending</p></div></article></li>,
#  <li class=""><article class="event-item clearfix" itemscope="" itemtype="http://data-vocabulary.org/Event"><span style="display:none;"><time datetime="2019-06-29T00:00" itemprop="startDate">2019-06-29T00:00</time></span><a href="/events/1282849"><img height="76" src="/images/events/flyer/2019/6/uk-0629-1282849-list.jpg" width="152"/></a><div class="bbox"><h1 class="event-title" itemprop="summary"><a href="/events/1282849" itemprop="url" title="Event details of Strange Riddims present: Hagan, Tamtam, Down2earth">Strange Riddims present: Hagan, Tamtam, Down2earth</a> <span>at <a href="/club.aspx?id=14042">Soup Kitchen</a></span></h1><div class="grey event-lineup">Strange Riddims, TamTam, Hagan, Down2earth</div><p class="attending"><span>1</span> Attending</p></div></article></li>,
#  <li><div class="but myra mt16" style="width: 152px;"><a href="/submit-event.aspx?ai=344">Submit event</a></div></li>]

# %%
date = entries[0].find('p', class_='eventDate date')
date.find('span').text
# Out:
# 'Fri, 28 Jun 2019 /'

# %%
def scrape_events(events_page_url):
    response = requests.get('https://www.residentadvisor.net/events')
    soup = BeautifulSoup(response.content, 'html.parser')
    event_listings = soup.findAll('li', id="event-listing")
    rows = []
    
    for event in event_listings:
        date = event.find('p', class_='eventDate date')
        final_date = date.find('span').text
        rows.append(final_date)
        
    return event_listings

# %%
scrape_events('https://www.residentadvisor.net/events')
# Out:
# []

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    #Your code here
    return next_page_url

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully scraped a website for concert event information!
